# %%
import tensorflow as tf
from pathlib import Path

mnist=tf.keras.datasets.mnist.load_data()
(x_train,y_train),(x_test,y_test)=mnist
x_train,x_val=x_train[:-5000],x_train[-5000:]
y_train,y_val=y_train[:-5000],y_train[-5000:]

model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28,28],dtype=tf.uint8),
    tf.keras.layers.Rescaling(scale=1/255),
    tf.keras.layers.Dense(100,activation="relu"),
    tf.keras.layers.Dense(10,activation="softmax")
])
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),loss="sparse_categorical_crossentropy",metrics=["accuracy"])
model.fit(x_train,y_train,validation_data=(x_val,y_val),epochs=20)
# Out:
# Epoch 1/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5692 - loss: 1.6857 - val_accuracy: 0.7812 - val_loss: 1.1586
# Epoch 2/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7877 - loss: 0.9750 - val_accuracy: 0.8602 - val_loss: 0.7288
# Epoch 3/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8348 - loss: 0.7146 - val_accuracy: 0.8838 - val_loss: 0.5572
# Epoch 4/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8565 - loss: 0.5959 - val_accuracy: 0.8952 - val_loss: 0.4701
# Epoch 5/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8673 - loss: 0.5285 - val_accuracy: 0.9036 - val_loss: 0.4173
# Epoch 6/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8752 - loss: 0.4848 - val_accuracy: 0.9078 - val_loss: 0.3827
# Epoch 7/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8804 - loss: 0.4540 - val_accuracy: 0.9096 - val_loss: 0.3579
# Epoch 8/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8851 - loss: 0.4309 - val_accuracy: 0.9118 - val_loss: 0.3395
# Epoch 9/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8886 - loss: 0.4129 - val_accuracy: 0.9134 - val_loss: 0.3252
# Epoch 10/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8920 - loss: 0.3983 - val_accuracy: 0.9164 - val_loss: 0.3135
# Epoch 11/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8942 - loss: 0.3861 - val_accuracy: 0.9186 - val_loss: 0.3038
# Epoch 12/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8964 - loss: 0.3757 - val_accuracy: 0.9184 - val_loss: 0.2958
# Epoch 13/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8985 - loss: 0.3668 - val_accuracy: 0.9216 - val_loss: 0.2881
# Epoch 14/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8999 - loss: 0.3588 - val_accuracy: 0.9222 - val_loss: 0.2821
# Epoch 15/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9017 - loss: 0.3517 - val_accuracy: 0.9240 - val_loss: 0.2765
# Epoch 16/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9029 - loss: 0.3453 - val_accuracy: 0.9248 - val_loss: 0.2719
# Epoch 17/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9048 - loss: 0.3395 - val_accuracy: 0.9266 - val_loss: 0.2672
# Epoch 18/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9060 - loss: 0.3341 - val_accuracy: 0.9264 - val_loss: 0.2632
# Epoch 19/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9071 - loss: 0.3292 - val_accuracy: 0.9284 - val_loss: 0.2596
# Epoch 20/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9085 - loss: 0.3245 - val_accuracy: 0.9292 - val_loss: 0.2560

# %%
model_name="mnist"
model_version="001"
model_path=Path(model_name)/model_version
model.export(model_path)
# Out:
# INFO:tensorflow:Assets written to: mnist\001\assets
# INFO:tensorflow:Assets written to: mnist\001\assets
# Saved artifact at 'mnist\001'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='keras_tensor_18')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   2038804323536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2038804321616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2038804322000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2038804324304: TensorSpec(shape=(), dtype=tf.resource, name=None)
